# %% [markdown]
# <a href="https://colab.research.google.com/github/MkShaon/Machine-Learning-and-Deep-Learning/blob/main/3_2_Complete_Pandas_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas Library:
# Useful for Data Processing & Analysis
#
# Pandas DataFrame is two-dimensional tabular data structure with labeled axes(rows & columns)

# %%
#importing pandas library
import pandas as pd
import numpy as np

# %% [markdown]
# #Creating Pandas DataFrame

# %%
# importing the boston house price data
from sklearn.datasets import load_diabetes

# %%
load_diabetes = load_diabetes()

# %%
type(load_diabetes)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(load_diabetes)
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]]), 'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
#pandas DataFrame
diab_df = pd.DataFrame(load_diabetes.data, columns = load_diabetes.feature_names)

# %%
diab_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
diab_df.shape
# Out:
# (442, 10)

# %% [markdown]
# #Importing data to a CSV file to pandas Dataframe

# %%
# csv file to pandas df
diabetes_df = pd.read_csv('/content/diabetes.csv')

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# #Loading the data from Excel file to pandas DataFrame
#
# pd.read_excel('file path')

# %% [markdown]
# #Exporting data to CSV file

# %%
diab_df.to_csv('diab.csv')

# %% [markdown]
# #Exporting the Pandas DataFrame to an Excel File:
# df.to_excel('filename')

# %% [markdown]
# # Create DataFrame with random values

# %%
#creating a DataFrame with random values
#all values will be between 0 to 1 i.e. 0.7456465, 0.647364, 0.745734.
random_df = pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.620013  0.728908  0.070027  0.892513  0.242215  0.414566  0.594566
# 1  0.774122  0.798263  0.392134  0.379411  0.593943  0.054930  0.904338
# 2  0.239863  0.737154  0.061111  0.318302  0.105299  0.944064  0.463369
# 3  0.572959  0.824397  0.018462  0.783739  0.500338  0.660980  0.158244
# 4  0.496305  0.934716  0.498286  0.913480  0.447851  0.509634  0.875901
#
#           7         8         9
# 0  0.790436  0.244001  0.733376
# 1  0.822799  0.084035  0.280084
# 2  0.049729  0.409589  0.209852
# 3  0.737633  0.580563  0.855274
# 4  0.355674  0.185834  0.251714

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# #Inspecting a DataFrame

# %%
#finding the number of rows and columns
diab_df.shape
# Out:
# (442, 10)

# %%
#print first 5 rows in a DataFrame
diab_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
#print last 5 rows of the DataFrame
diab_df.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064

# %%
#information about the DataFrame
diab_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
#find the number of missing values
diab_df.isnull().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
#diabetes dataframe
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# counting the values based on the labels
diabetes_df.value_counts('Outcome')
#diabetes_df.value_counts('Age')
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
# Group the values based on the MEAN
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# #Statistical Measures

# %%
# count or number of values
diab_df.count()
# Out:
# age    442
# sex    442
# bmi    442
# bp     442
# s1     442
# s2     442
# s3     442
# s4     442
# s5     442
# s6     442
# dtype: int64

# %%
#mean value column wise
diab_df.mean()
# Out:
# age   -1.444295e-18
# sex    2.543215e-18
# bmi   -2.255925e-16
# bp    -4.854086e-17
# s1    -1.428596e-17
# s2     3.898811e-17
# s3    -6.028360e-18
# s4    -1.788100e-17
# s5     9.243486e-17
# s6     1.351770e-17
# dtype: float64

# %%
#standard deviation - column wise
diab_df.std()
# Out:
# age    0.047619
# sex    0.047619
# bmi    0.047619
# bp     0.047619
# s1     0.047619
# s2     0.047619
# s3     0.047619
# s4     0.047619
# s5     0.047619
# s6     0.047619
# dtype: float64

# %%
#minimum value
diab_df.min()
# Out:
# age   -0.107226
# sex   -0.044642
# bmi   -0.090275
# bp    -0.112399
# s1    -0.126781
# s2    -0.115613
# s3    -0.102307
# s4    -0.076395
# s5    -0.126097
# s6    -0.137767
# dtype: float64

# %%
#maximum value
diab_df.max()
# Out:
# age    0.110727
# sex    0.050680
# bmi    0.170555
# bp     0.132044
# s1     0.153914
# s2     0.198788
# s3     0.181179
# s4     0.185234
# s5     0.133597
# s6     0.135612
# dtype: float64

# %%
#all the statistical measure about the dataframe
diab_df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...

# %% [markdown]
# # # Manipulating a DataFrame

# %%
# adding a column
diab_df['Result: '] = load_diabetes.target

# %%
diab_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6     Price
# 0 -0.002592  0.019907 -0.017646 -0.017646
# 1 -0.039493 -0.068332 -0.092204 -0.092204
# 2 -0.002592  0.002861 -0.025930 -0.025930
# 3  0.034309  0.022688 -0.009362 -0.009362
# 4 -0.002592 -0.031988 -0.046641 -0.046641

# %%
# removing a row
diab_df.drop(index = 0, axis=0)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6     Price  Result:
# ...

# %%
# remove a column
diab_df.drop(columns='age', axis = 1)
# Out:
#           sex       bmi        bp        s1        s2        s3        s4  \
# 0    0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401 -0.002592
# 1   -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412 -0.039493
# 2    0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356 -0.002592
# 3   -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038  0.034309
# 4   -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142 -0.002592
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674 -0.002592
# 438  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674  0.034309
# 439  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993 -0.011080
# 440 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674  0.026560
# 441 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816 -0.039493
#
#            s5        s6     Price  Result:
# ...

# %%
# Locate specific row using index value
diab_df.iloc[2]
# Out:
# age           0.085299
# sex           0.050680
# bmi           0.044451
# bp           -0.005670
# s1           -0.045599
# s2           -0.034194
# s3           -0.032356
# s4           -0.002592
# s5            0.002861
# s6           -0.025930
# Price        -0.025930
# Result:     141.000000
# Name: 2, dtype: float64

# %%
# locate specific clumns
print(diab_df.iloc[:, 0]) # first column
# Out:
# 0      0.038076
# 1     -0.001882
# 2      0.085299
# 3     -0.089063
# 4      0.005383
#          ...
# 437    0.041708
# 438   -0.005515
# 439    0.041708
# 440   -0.045472
# 441   -0.045472
# Name: age, Length: 442, dtype: float64

# %% [markdown]
# # Co-relation
# 1. Positive Corelation
# 2. Negative Corelation

# %%
diab_df.corr()
# Out:
#                age       sex       bmi        bp        s1        s2  \
# age       1.000000  0.173737  0.185085  0.335428  0.260061  0.219243
# sex       0.173737  1.000000  0.088161  0.241010  0.035277  0.142637
# bmi       0.185085  0.088161  1.000000  0.395411  0.249777  0.261170
# bp        0.335428  0.241010  0.395411  1.000000  0.242464  0.185548
# s1        0.260061  0.035277  0.249777  0.242464  1.000000  0.896663
# s2        0.219243  0.142637  0.261170  0.185548  0.896663  1.000000
# s3       -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455
# s4        0.203841  0.332115  0.413807  0.257650  0.542207  0.659817
# s5        0.270774  0.149916  0.446157  0.393480  0.515503  0.318357
# s6        0.301731  0.208133  0.388680  0.390430  0.325717  0.290600
# Price     0.301731  0.208133  0.388680  0.390430  0.325717  0.290600
# Result:   0.187889  0.043062  0.586450  0.441482  0.212022  0.174054
#
#                 s3        s4        s5        s6     Price  Result:
# ...
